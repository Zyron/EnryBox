# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/average/data_20008813_15_11_2020_15_12_2020_average.csv")

# %%
data
# Out:
#                         time  g avg  g high  g low  °C avg  °C high  °C low  \
# 0    12/15/2020  12:00:00 AM  0.039   0.052  0.022      25       25      25
# 1    12/14/2020  11:00:00 PM  0.036   0.046  0.018      25       25      25
# 2    12/14/2020  10:00:00 PM  0.039   0.052  0.022      25       25      25
# 3     12/14/2020  9:00:00 PM  0.321   4.676  0.023      25       25      25
# 4     12/14/2020  8:00:00 PM  0.272   4.497  0.025      25       26      25
# ..                       ...    ...     ...    ...     ...      ...     ...
# 715   11/15/2020  4:00:00 AM  0.038   0.056  0.025      25       25      25
# 716   11/15/2020  3:00:00 AM  0.038   0.056  0.020      25       25      25
# 717   11/15/2020  2:00:00 AM  0.037   0.057  0.023      25       25      25
# 718   11/15/2020  1:00:00 AM  0.037   0.053  0.018      25       25      25
# 719  11/15/2020  12:00:00 AM  0.038   0.048  0.026      25       25      25
#
#      sample qty  rssi avg  rssi high  rssi low
# ...

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
plt.figure()

# %%
In [3]: ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

In [4]: ts = ts.cumsum()

In [5]: ts.plot();

# %%
In [6]: df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list("ABCD"))

In [7]: df = df.cumsum()

In [8]: plt.figure();

In [9]: df.plot();

# %%
In [20]: df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

In [21]: df2.plot.bar();

# %%
In [60]: df = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

In [61]: df.plot.area();

# %%
In [62]: df.plot.area(stacked=False);

# %%
data.plot.area(stacked=False);

# %%
data2 = data.DataFrame(data, columns=["g avg", "sample qty"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-3bbc879c6187> in <module>
# ----> 1 data2 = data.DataFrame(data, columns=["g avg", "sample qty"])
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'

# %%
data3 = data[["time", "sample qty"]]

# %%
data3.plot()
# Out:
# <AxesSubplot:>

# %%
data2 = data[["time", "g avg"]]

# %%
data2.plot()
# Out:
# <AxesSubplot:>

# %%
data2.plot.area(stacked=False);

# %%
datarawdata = pd.read_csv("data_20008813_15_11_2020_15_12_2020_rawdata.csv")

# %%
datarawdata.plot()
# Out:
# <AxesSubplot:>

# %%
raw = datarawdata[["time", "g"]]

# %%
raw.plot()
# Out:
# <AxesSubplot:>

# %%
raw.head()
# Out:
#                       time      g
# 0  12/14/2020  11:59:32 PM  0.040
# 1  12/14/2020  11:57:32 PM  0.025
# 2  12/14/2020  11:55:32 PM  0.041
# 3  12/14/2020  11:53:31 PM  0.033
# 4  12/14/2020  11:51:31 PM  0.040

# %%
raw2 = raw[raw["g"] > 0.1]

# %%
raw2.head()
# Out:
#                       time      g
# 71  12/14/2020  9:38:50 PM  0.127
# 72  12/14/2020  9:38:49 PM  0.230
# 73  12/14/2020  9:38:46 PM  0.368
# 74  12/14/2020  9:38:45 PM  0.838
# 75  12/14/2020  9:38:43 PM  0.172

# %%
raw2.plot()
# Out:
# <AxesSubplot:>

# %%
raw2
# Out:
#                         time      g
# 71    12/14/2020  9:38:50 PM  0.127
# 72    12/14/2020  9:38:49 PM  0.230
# 73    12/14/2020  9:38:46 PM  0.368
# 74    12/14/2020  9:38:45 PM  0.838
# 75    12/14/2020  9:38:43 PM  0.172
# ...                      ...    ...
# 1994  12/14/2020  3:17:52 PM  0.153
# 1995  12/14/2020  3:17:51 PM  0.270
# 1996  12/14/2020  3:17:50 PM  0.806
# 1998  12/14/2020  3:17:42 PM  0.187
# 1999  12/14/2020  3:17:41 PM  0.407
#
# [1412 rows x 2 columns]

# %%
raw2.plot.area(stacked=False);

# %%
raw
# Out:
#                          time      g
# 0     12/14/2020  11:59:32 PM  0.040
# 1     12/14/2020  11:57:32 PM  0.025
# 2     12/14/2020  11:55:32 PM  0.041
# 3     12/14/2020  11:53:31 PM  0.033
# 4     12/14/2020  11:51:31 PM  0.040
# ...                       ...    ...
# 1995   12/14/2020  3:17:51 PM  0.270
# 1996   12/14/2020  3:17:50 PM  0.806
# 1997   12/14/2020  3:17:45 PM  0.080
# 1998   12/14/2020  3:17:42 PM  0.187
# 1999   12/14/2020  3:17:41 PM  0.407
#
# [2000 rows x 2 columns]

# %%
data3
# Out:
#                         time  sample qty
# 0    12/15/2020  12:00:00 AM          30
# 1    12/14/2020  11:00:00 PM          30
# 2    12/14/2020  10:00:00 PM          30
# 3     12/14/2020  9:00:00 PM         327
# 4     12/14/2020  8:00:00 PM         182
# ..                       ...         ...
# 715   11/15/2020  4:00:00 AM          30
# 716   11/15/2020  3:00:00 AM          30
# 717   11/15/2020  2:00:00 AM          30
# 718   11/15/2020  1:00:00 AM          29
# 719  11/15/2020  12:00:00 AM          30
#
# [720 rows x 2 columns]

# %%
qty = data3[data3["sample qty"] > 30]

# %%
qty
# Out:
#                        time  sample qty
# 3    12/14/2020  9:00:00 PM         327
# 4    12/14/2020  8:00:00 PM         182
# 5    12/14/2020  7:00:00 PM         417
# 6    12/14/2020  6:00:00 PM         327
# 7    12/14/2020  5:00:00 PM         299
# ..                      ...         ...
# 701  11/15/2020  6:00:00 PM         106
# 702  11/15/2020  5:00:00 PM         442
# 704  11/15/2020  3:00:00 PM          35
# 705  11/15/2020  2:00:00 PM         503
# 706  11/15/2020  1:00:00 PM         121
#
# [357 rows x 2 columns]

# %%
qty.plot.area(stacked=False);

# %%
qty = data3[data3["sample qty"] > 500]

# %%
qty.plot.area(stacked=False);

# %%
qty.plot.area();

# %%
qty.plot();

# %%
qty = data3[data3["sample qty"] > 650]

# %%
qty.plot()
# Out:
# <AxesSubplot:>

# %%
qty.sort_values(by='time', ascending=False)
# Out:
#                         time  sample qty
# 318    12/1/2020  5:00:00 PM         797
# 319    12/1/2020  4:00:00 PM         685
# 322    12/1/2020  1:00:00 PM         656
# 369   11/29/2020  2:00:00 PM         688
# 392   11/28/2020  3:00:00 PM         685
# 417   11/27/2020  2:00:00 PM         718
# 420  11/27/2020  11:00:00 AM         699
# 439   11/26/2020  4:00:00 PM         783
# 441   11/26/2020  2:00:00 PM         681
# 462   11/25/2020  5:00:00 PM         682
# 485   11/24/2020  6:00:00 PM         665
# 560   11/21/2020  3:00:00 PM         654

# %%
qty.sort_values(by='time', ascending=True)
# Out:
#                         time  sample qty
# 560   11/21/2020  3:00:00 PM         654
# 485   11/24/2020  6:00:00 PM         665
# 462   11/25/2020  5:00:00 PM         682
# 441   11/26/2020  2:00:00 PM         681
# 439   11/26/2020  4:00:00 PM         783
# 420  11/27/2020  11:00:00 AM         699
# 417   11/27/2020  2:00:00 PM         718
# 392   11/28/2020  3:00:00 PM         685
# 369   11/29/2020  2:00:00 PM         688
# 322    12/1/2020  1:00:00 PM         656
# 319    12/1/2020  4:00:00 PM         685
# 318    12/1/2020  5:00:00 PM         797
